# %%
#Ej 1
f(x)=tan(x)-1/x-1
f
# Out:
# x |--> -1/x + tan(x) - 1

# %%
plot(f,(x,-5,5))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
F(x)=sin(x)*(x-1)-cos(x)
F
# Out:
# x |--> (x - 1)*sin(x) - cos(x)

# %%
plot(F,-4,0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(F,-0.75,-0.25)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(F,-3.5,-3)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=-0.75
b=-0.25
a0=a
b0=b
c0=(a0+b0)/2
c0
# Out:
# -0.500000000000000

# %%
F(a0),F(c0),F(b0)
# Out:
# (0.461178961167014, -0.158444253984068, -0.659657472642491)

# %%
a1=a0
b1=c0
c1=(a1+b1)/2
c1
# Out:
# -0.625000000000000

# %%
F(a1),F(c1),F(b1)
# Out:
# (0.461178961167014, 0.139819949023033, -0.158444253984068)

# %%
a2=c1
b2=b1
c2=(a2+b2)/2
c2
# Out:
# -0.562500000000000

# %%
F(a2),F(c2),F(b2)
# Out:
# (0.139819949023033, -0.0126390718310365, -0.158444253984068)

# %%
a=-0.75
b=-0.25
epsilon=10^(-8)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
a,b
# Out:
# (-0.750000000000000, -0.250000000000000)

# %%
cont=0
N=25
a0=a
b0=b
c0=(a0+b0)/2

# %%
while not F(c0)==0 and cont<N:
    if F(a0)*F(c0)<0:
        b0=c0
        c0=(b0+a0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    cont = cont +1
c0
# Out:
# -0.567782022058964

# %%
show(cont)
# Out:
# 25

# %%
show(F(c0))
# Out:
# 3.36311256621258e-9

# %%
show(find_root(F(x),a,b))
abs(c0-find_root(F(x),a,b))<10^(-8)
# Out:
# -0.5677820206560978
# True

# %%
a=-3.5
b=-3
epsilon=10^(-8)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
cont=0
N=25
a0=a
b0=b
c0=(b0+a0)/2

# %%
while not f(c0)==0 and cont<N:
    if(F(a0)*F(c0)<0):
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(b0+a0)/2
    cont=cont+1
c0
# Out:
# -3.36671587079763

# %%
cont
F(c0)
# Out:
# 3.17345564271321e-8

# %%
find_root(F(x),a,b)
abs(c0-find_root(F(x),a,b))<10^(-8)
# Out:
# True

# %%
#Ej 2
f(x)=e^(x)-e^(-x)-x^(3)+1
f
# Out:
# x |--> -x^3 - e^(-x) + e^x + 1

# %%
plot(f,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,-5,-4.5)
# Out:
# -4.567345052205097

# %%
plot(f,-5,-4.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,4.1,4.6)
# Out:
# 4.504046043991592

# %%
plot(f,4.1,4.6)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,-1.5,-1)
# Out:
# -1.4387411181880254

# %%
plot(f,-1.5,-1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,2,2.5)
# Out:
# 2.0550905428661803

# %%
plot(f,2,2.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,-1,-0.5)
# Out:
# -0.5572202762229479

# %%
plot(f,-1,-0.5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=-1
b=-0.5
a0=a
b0=b
c0=(a0+b0)/2
c0
# Out:
# -0.750000000000000

# %%
f(a0).n(),f(c0),f(b0)
# Out:
# (-0.350402387287603, -0.222758463871660, 0.0828093890125052)

# %%
a1=c0
b1=b0
c1=(a1+b1)/2
c1
# Out:
# -0.625000000000000

# %%
f(a1),f(c1),f(b1)
# Out:
# (-0.222758463871660, -0.0888439039132320, 0.0828093890125052)

# %%
a2=c1
b2=b1
c2=(a2+b2)/2
c2
# Out:
# -0.562500000000000

# %%
f(c2)
# Out:
# -0.00729331660437549

# %%
a=-1
b=-0.5
epsilon=10^(-8)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
N=25

# %%
cont=0
a0=a
b0=b
c0=(b0+a0)/2
while not f(c0)==0 and cont<N:
    if f(a0)*f(c0)<0:
        b0=c0
        c0=(b0+a0)/2
    else:
        a0=c0
        c0=(b0+a0)/2
    cont = cont+1
c0
# Out:
# -0.557220272719860

# %%
cont
# Out:
# 25

# %%
c0-find_root(f,a,b)<epsilon
# Out:
# True

# %%
a=2
b=2.5
epsilon=10^(-8)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
cont=0
N=25
a0=a
b0=b
c0=(b0+a0)/2
while not f(c0)==0 and cont<N:
    if f(a0)*f(c0)<0:
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    cont=cont +1
c0
# Out:
# 2.05509053915739

# %%
c0-find_root(f,a,b)<epsilon
# Out:
# True

# %%
a=4.1
b=4.6
epsilon=10^(-8)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
contador=0
N=25
a0=a
b0=b
c0=(b0+a0)/2
while not f(c0)==0 and contador<N:
    if f(a0)*f(c0)<0:
        b0=c0
        c0=(b0+a0)/2  
    else:
        a0=c0
        c0=(b0+a0)/2
    contador=contador+1
c0
# Out:
# 4.50404605120420

# %%
abs(c0-find_root(f,a,b))<epsilon
# Out:
# True

# %%
#Ej3
f(x)=sin(x)*ln(x)-1
f
# Out:
# x |--> log(x)*sin(x) - 1

# %%
plot(f,0,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,6.5,7)
# Out:
# 6.830565304517519

# %%
plot(f,6.5,7)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,8.5,9)
# Out:
# 8.950997825362238

# %%
plot(f,8.5,9)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=6.5
b=7
epsilon=10^(-6)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 17.9315685693242

# %%
cont=0
a0=a
b0=b
N=18
c0=(a0+b0)/2

# %%
while not (f(c0)==0) and cont<N:
    if f(a0)*f(c0)<0:
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    cont = cont +1
c0
# Out:
# 6.83056545257568

# %%
c0-find_root(f(x),a,b)<epsilon
# Out:
# True

# %%
#Ej 4
f(x)=x^2+10*cos(x)
f
# Out:
# x |--> x^2 + 10*cos(x)

# %%
plot(f,-4,4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,-3.4,-2.9)
# Out:
# -3.1619500247102557

# %%
plot(f,-3.4,-2.9)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,1.4,2.1)
# Out:
# 1.9688729378198273

# %%
plot(f,1.4,2.1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=1.4
b=2.1
epsilon=10^(-5)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 15.0950673016071

# %%
a0=a
b0=b
c0=(a0+b0)/2
cont=0
N=16
c0
# Out:
# 1.75000000000000

# %%
f(a0), f(c0), f(b0)
# Out:
# (3.65967142900241, 1.28003944350508, -0.638461045998575)

# %%
a1=c0
b1=b0
c1=(a1+b1)/2
c1
# Out:
# 1.92500000000000

# %%
f(a1),f(c1),f(b1)
# Out:
# (1.28003944350508, 0.237189179183273, -0.638461045998575)

# %%
a2=c1
b2=b1
c2=(a2+b2)/2
c2
# Out:
# 2.01250000000000

# %%
f(a2),f(c2),f(b2)
# Out:
# (0.237189179183273, -0.224646223412389, -0.638461045998575)

# %%
while abs(f(c0))>0 and cont<N:
    if(f(c0)*f(a0)<0):
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    cont = cont +1
c0
cont
# Out:
# 16

# %%
c0-find_root(f,a,b)<epsilon
# Out:
# True

# %%
a=3
b=4
epsilon=10^(-5)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 15.6096404744368

# %%
a0=a
b0=b
c0=(a0+b0)/2
cont=0
N=16
c0
# Out:
# 7/2

# %%
while abs(f(c0))>0 and cont<16:
    if f(a0)*f(c0)<0:
        b0=c0
        c0=(b0+a0)/2  
    else:
        a0=c0
        c0=(b0+a0)/2
    cont=cont+1
print(cont)
# Out:
# 16

# %%
c0-find_root(f,a,b)<epsilon
# Out:
# True

# %%
#Ej 5
f(x)=x*e^x-1
f
# Out:
# x |--> x*e^x - 1

# %%
plot(f,x,0,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,0.5,0.6)
# Out:
# 0.5671432904096737

# %%
a=0.5
b=0.6
epsilon=10^(-5)
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 12.2877123795494

# %%
a0=a
b0=b
c0=(a0+b0)/2
N=13
cont=0

# %%
while not f(c0)==0 and cont<N:
    if(f(c0)*f(a0)<0):
        b0=c0
        c0=(b0+a0)/2
    else:
        a0=c0
        c0=(b0+a0)/2
    cont = cont +1
c0
# Out:
# 0.567144775390625

# %%
c0-find_root(f,0.5,0.6)<epsilon
# Out:
# True

# %%
#Ej 6
f(x)=2^(-x)+e^(x)+2*cos(x)-6
f
# Out:
# x |--> 1/2^x + 2*cos(x) + e^x - 6

# %%
plot(f,-3,2)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,-3.25,-2.75)
# Out:
# -2.9865080693819284

# %%
plot(f,-3.25,-2.75)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
find_root(f,1.4,1.9)
# Out:
# 1.8293836019338316

# %%
plot(f,1.4,1.9)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=-3.25
b=-2.75

# %%
a0=a
b0=b
c0=(a0+b0)/2
f(a0),f(c0),f(b0)
# Out:
# (1.56417177569240, 0.0698020751669731, -1.05750557402850)

# %%
a1=c0
b1=b0
c1=(a1+b1)/2
f(a1),f(c1),f(b1)
# Out:
# (0.0698020751669731, -0.536899807501486, -1.05750557402850)

# %%
a2=a1
b2=c1
c2=(a2+b2)/2
f(a2),f(c2),f(b2)
# Out:
# (0.0698020751669731, -0.244666270821096, -0.536899807501486)

# %%
epsilon=10^(-8)
numerical_approx(log((b-a)/10^(-8))/log(2)-1)
# Out:
# 24.5754247590989

# %%
epsilon=10^(-8)
epsilon
numerical_approx(log((b-a)/epsilon)/log(2)-1)
# Out:
# 24.5754247590989

# %%
N=25
contador=0
while not f(c0)==0 and contador<N:
    if f(c0)*f(a0)<0:
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    contador=contador+1
c0
# Out:
# -2.98650806397200

# %%
abs(c0-find_root(f,-3.25,-2.75))<epsilon
# Out:
# True

# %%
a=1.4
b=1.9
a0=a
b0=b
c0=(a0+b0)/2
numerical_approx(log((b-a)/epsilon)/log(2)-1)
N=25
contador=0
while not f(c0)==0 and contador<N:
    if f(c0)*f(a0)<0:
        b0=c0
        c0=(a0+b0)/2
    else:
        a0=c0
        c0=(a0+b0)/2
    contador=contador+1
c0
# Out:
# 1.82938359826803

# %%
abs(c0-find_root(f,1.4,1.9))<epsilon
# Out:
# True

# %%
#Ej 10
f(x)=sin(1/x)-x
f
# Out:
# x |--> -x + sin(1/x)

# %%
plot(f,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,0.8,1)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=0.8
b=1

# %%
find_root(f,a,b)
# Out:
# 0.8975394612804871

# %%
(f(a)*f(b)).n()
# Out:
# -0.0236183849852115

# %%
plot(diff(f(x),x),a,b) +plot(0,a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f;diff(f(x),x);diff(f(x),x,2)
# Out:
# 2*cos(1/x)/x^3 - sin(1/x)/x^4

# %%
plot(diff(f(x),x,2),(x,a,b))+plot(0,(x,a,b),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a=0.72
b=0.92
(f(a)*f(b)).n()
# Out:
# -0.00916579708769205

# %%
plot(diff(f(x),x),a,b) +plot(0,a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(diff(f(x),x,2),a,b) + plot(0, a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
d1(x)=diff(f(x),x)
d1
# Out:
# x |--> -cos(1/x)/x^2 - 1

# %%
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
x2=x1-f(x1)/d1(x1)
[x0,x1,x2]
# Out:
# [0.820000000000000, 0.898671241614135, 0.897539527027686]

# %%
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
x2=x1-f(x1)/d1(x1)
x3=x2-f(x2)/d1(x2)
abs(x3-x2)
# Out:
# 6.57471986853508e-8

# %%
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
x2=x1-f(x1)/d1(x1)
x3=x2-f(x2)/d1(x2)
x4=x3-f(x3)/d1(x3)
abs(x4-x3)
# Out:
# 3.33066907387547e-16

# %%
abs(x4-find_root(f,a,b)).n()<10^-8
# Out:
# True

# %%
#Ej 13
g(x)=(x-1)*sin(x)-1/(2*(1-x^2))
g
# Out:
# x |--> (x - 1)*sin(x) + 1/2/(x^2 - 1)

# %%
plot(g,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
f=numerator(g)
f
# Out:
# x |--> 2*x^3*sin(x) - 2*x^2*sin(x) - 2*x*sin(x) + 2*sin(x) + 1

# %%
plot(f,-10,10)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,-4,4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,-1,0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
a=-0.6
b=-0.4
find_root(f,a,b)
# Out:
# -0.4463914416206211

# %%
(f(a)*f(b)).n()
# Out:
# -0.0131503453179050

# %%
plot(diff(f(x),x),a,b) + plot(0, a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f;diff(f(x),x);diff(f(x),x,2)
# Out:
# -2*x^3*sin(x) + 12*x^2*cos(x) + 2*x^2*sin(x) - 8*x*cos(x) + 14*x*sin(x) - 4*cos(x) - 6*sin(x)

# %%
plot(diff(f(x),x,2),(x,a,b))+ plot(0,(x,a,b),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
b-a
# Out:
# 0.200000000000000

# %%
d1(x)=diff(f(x),x)
show(d1)
# Out:
# x |--> 2*x^3*cos(x) - 2*x^2*cos(x) + 6*x^2*sin(x) - 2*x*cos(x) - 4*x*sin(x) + 2*cos(x) - 2*sin(x)

# %%
numerical_approx(max(abs(f(a)/d1(a)),abs(f(b)/d1(b))))
# Out:
# 0.638832188701172

# %%
a=-0.5
b=-0.3
(f(a)*f(b)).n()
# Out:
# -0.0236751408560788

# %%
plot(diff(f(x),x),a,b)+plot(0,a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(diff(f(x),x,2),a,b) + plot(0, a,b,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
numerical_approx( max(abs(f(a)/d1(a)),abs(f(b)/d1(b))))
# Out:
# 0.128702789936546

# %%
N=50
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
contador=1
while contador<50 and abs(x1-x0)>10^(-9):
    contador=contador+1
    x0=x1
    x1=x0-f(x0)/d1(x0)

# %%
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
x2=x1-f(x1)/d1(x1)
x3=x2-f(x2)/d1(x2)
x4=x3-f(x3)/d1(x3)
abs(x4-x3)
# Out:
# 8.88463635995151e-10

# %%
x1
# Out:
# -0.446391441620621

# %%
find_root(f,a,b)
# Out:
# -0.44639144162061234

# %%
x4-find_root(f,a,b)
# Out:
# -8.71525074330748e-15

# %% [markdown]
# #Ej 14
# Vamos a aplicar el método de Newton para aproximar la raíz positiva de la ecuación
# x^3+94x^2−389x+295
# (a) Localiza y separa gráficamente todas sus soluciones en intervalos de anchura 0.5.
# (b) Realiza manualmente dos pasos del método de Newton empezando en x0=2. ¿Qué ocurre?
# (c) Sea α la solución negativa de la ecuación. Encuentra un intervalo de anchura 0.5 al que pertenezca α y en el que se cumplan las condiciones del “Teorema de convergencia global” del método de Newton.
# (d) Calcula aproximadamente α mediante el método de Newton, deteniendo el algoritmo cuando la distancia entre dos iteraciones consecutivas sea menor que 10^-10
# (e) Utiliza el comando “find root” para resolver la ecuación en el intervalo del apartado (c) y compara la solución obtenida con la del apartado (d).

# %%
f(x)=x^3+94*x^2-389*x+295
f
# Out:
# x |--> x^3 + 94*x^2 - 389*x + 295

# %%
plot(f,-5,5)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,-105,0)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,0,4)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
plot(f,-98.25,-97.75)
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
d1=diff(f,x)
d2=diff(f,x,2)

# %%
x0=2
x1=x0-f(x0)/d1(x0)
x2=x1-f(x1)/d1(x1)
x2.n()
# Out:
# -98.0207248489898

# %%
plot(f,0.5,3)+plot(d1(2)*(x-x0)+f(2),0.5,3,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
b=-97.75
a=-98.25
b-a
# Out:
# 0.500000000000000

# %%
f(a)*f(b)

# %% [markdown]
# Sea f:[a,b]→ℝ de clase C2 en [a,b], cumpliendo las condiciones:
#
# i) f(a)f(b)<0.
#
# ii) f′(x)≠0∀x∈[a,b].
#
# iii) f″(x) no cambia de signo en [a,b].
#
# iv) max{|||f(a)f′(a)|||,|||f(b)f′(b)|||}≤b−a.

# %%
plot(diff(f(x),x),(x,a,b)) + plot(0,(x,a,b),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
f,diff(f(x),x),diff(f(x),x,2)
# Out:
# (x |--> x^3 + 94*x^2 - 389*x + 295, 3*x^2 + 188*x - 389, 6*x + 188)

# %%
plot(diff(f(x),x,2),(x,a,b)) + plot(0,(x,a,b),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
b-a
# Out:
# 0.500000000000000

# %%
numerical_approx( max(abs(f(a)/d1(a)),abs(f(b)/d1(b))) )
# Out:
# 0.251360591462683

# %%
eps=10^(-10)

# %%
contador =1
N=50 # Nº máximo de iteraciones (por si el criterio de parada no se detiene)
x0=(a+b)/2
x1=x0-f(x0)/d1(x0)
while abs(x0-x1)>eps and contador < 50:
    x0=x1
    x1=x0-f(x0)/d1(x0)
    contador=contador + 1
print('La solución aproximada es', x1)
# Out:
# La solución aproximada es -98.0001000098009

# %%
contador
# Out:
# 3

# %%
find_root(f,a,b)
# Out:
# -98.00010000980093
