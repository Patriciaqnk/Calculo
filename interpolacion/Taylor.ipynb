# %%
#Ej1
f(x)=cos(x)+sin(x)
f
# Out:
# x |--> cos(x) + sin(x)

# %%
P(x)=taylor(f,x,0,5)
P
# Out:
# x |--> 1/120*x^5 + 1/24*x^4 - 1/6*x^3 - 1/2*x^2 + x + 1

# %%
plot(f,(x,-3,3),color='red')+plot(P,(x,-3,3))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(f,(x,-3,3),legend_label='y=f(x)$',color='red')+plot(P,(x,-3,3),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(0.1)
aprox
# Out:
# 1.09483758333333

# %%
cota=2*0.1^6/factorial(6)
cota
# Out:
# 2.77777777777778e-9

# %%
error=abs(f(0.1)-P(0.1))
error
# Out:
# 1.40847955520940e-9

# %%
error.n()<cota.n()
# Out:
# True

# %%
plot(abs(diff(f(x),x,6)),(x,0,0.1),gridlines='true')+plot(1.1,(x,0,0.1),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
#Ej2
f(x)=e^(3*x)
f
# Out:
# x |--> e^(3*x)

# %%
P(x)=taylor(f,x,0,3)
P
# Out:
# x |--> 9/2*x^3 + 9/2*x^2 + 3*x + 1

# %%
plot(f,(x,-3,3),color='red')+plot(P,(x,-3,3))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(f,(x,-3,3),legend_label='y=f(x)$',color='red')+plot(P,(x,-3,3),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(0.1)
aprox
# Out:
# 1.34950000000000

# %% [markdown]
# Buscamos la cota gráficamente

# %%
plot(diff(f(x),x,4),(x,0,0.1))+plot(110,(x,0,0.1))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
cota=110*0.1^4/factorial(4)
cota
error=abs(f(0.1)-P(0.1))
error.n()<cota.n()
# Out:
# True

# %%
#Ej3
f(x)=(e^x+e^(-x))/2
f
# Out:
# x |--> 1/2*e^(-x) + 1/2*e^x

# %%
P(x)=taylor(f,x,0,4)
P
# Out:
# x |--> 1/24*x^4 + 1/2*x^2 + 1

# %%
plot(f,(x,-3,3),color='red',legend_label='y=f(x)$')+plot(P,(x,-3,3),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(0.1)
aprox
# Out:
# 1.00500416666667

# %%
plot(diff(f,x,5),(x,0,0.10))+plot(0.11,(x,0,0.1))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
cota=0.11*0.1^(5)/factorial(5)
error=abs(f(0.1)-P(0.1))
error.n()<cota.n()
# Out:
# True

# %%
#Ej4
f(x)=log(x)
f
# Out:
# x |--> log(x)

# %%
P(x)=taylor(f,x,2,4)
P
# Out:
# x |--> -1/64*(x - 2)^4 + 1/24*(x - 2)^3 - 1/8*(x - 2)^2 + 1/2*x + log(2) - 1

# %%
plot(f,(x,0,4),legend_label='y=f(x)$',color='red')+plot(P,(x,0,4),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(2.5).n()
aprox
# Out:
# 0.916128951393279

# %%
plot(diff(f,x,5),(x,2,2.5))+plot(0.76,(x,2,2.5))
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
cota=0.76*0.5^5/factorial(5)
cota
error=abs(f(2.5)-P(2.5))
error.n()
error.n()<cota.n()
# Out:
# True

# %%
#Ej5
f(x)=sin(x)
f
# Out:
# x |--> sin(x)

# %%
cota(n)=(0.15)^(n+1)/factorial(n+1)

# %%
n=1
while cota(n)>=10^(-6):
    n=n+1
n
# Out:
# 4

# %%
P(x)=taylor(f,x,0,4)
P
# Out:
# x |--> -1/6*x^3 + x

# %%
plot(f,(x,-3,3),color='red',legend_label='y=f(x)$')+plot(P,(x,-3,3),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(0.15)
aprox.n()
# Out:
# 0.149437500000000

# %%
error=abs(f(0.15)-P(0.15))
error.n()<10^(-6).n()
# Out:
# True

# %%
plot(abs(f(x)-P(x)),(x,-0.25,0.25))+plot(10^(-6),(x,-0.25,0.25),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a=find_root(abs(f(x)-P(x))-10^(-6),-0.2,-0.1)
a
# Out:
# -0.16439633760340988

# %%
b=find_root(abs(f(x)-P(x))-10^(-6),0.2,0.1)
b
# Out:
# 0.16439633760340988

# %%
[a,b]
# Out:
# [-0.16439633760340988, 0.16439633760340988]

# %%
#Ej 6
f(x) = 2*sin(x)+cos((5*x)/3)
f
# Out:
# x |--> cos(5/3*x) + 2*sin(x)

# %%
show(diff(f,x))
show(diff(f,x,2))
show(diff(f,x,3))
show(diff(f,x,4))
show(diff(f,x,5))
show(diff(f,x,6))
# Out:
# x |--> 2*cos(x) - 5/3*sin(5/3*x)
# x |--> -25/9*cos(5/3*x) - 2*sin(x)
# x |--> -2*cos(x) + 125/27*sin(5/3*x)
# x |--> 625/81*cos(5/3*x) + 2*sin(x)
# x |--> 2*cos(x) - 3125/243*sin(5/3*x)
# x |--> -15625/729*cos(5/3*x) - 2*sin(x)

# %%
M(n)=2+(5/3)^(n+1)
cota(n)=M(n)*(0.45)^(n+1)/factorial(n+1)

# %%
n=1
while cota(n)>=10^(-6):
    n=n+1
n
# Out:
# 8

# %%
P(x)=taylor(f,x,0,n)
P
# Out:
# x |--> 78125/52907904*x^8 - 1/2520*x^7 - 3125/104976*x^6 + 1/60*x^5 + 625/1944*x^4 - 1/3*x^3 - 25/18*x^2 + 2*x + 1

# %%
plot(f,(x,-3,3),color='red',legend_label='y=f(x)$')+plot(P,(x,-3,3),legend_label='x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
aprox=P(0.45)
aprox
# Out:
# 1.60161994838610

# %%
error=abs(f(0.45)-P(0.45))
error.n()<10^(-6).n()
# Out:
# True

# %%
#Ej 7
f(x)=sin(x)-cos(x)
f
# Out:
# x |--> -cos(x) + sin(x)

# %%
show(diff(f,x))
show(diff(f,x,2))
show(diff(f,x,3))
show(diff(f,x,4))
show(diff(f,x,5))
# Out:
# x |--> cos(x) + sin(x)
# x |--> cos(x) - sin(x)
# x |--> -cos(x) - sin(x)
# x |--> -cos(x) + sin(x)
# x |--> cos(x) + sin(x)

# %%
cota(n)=2*(0.1)^(n+1)/factorial(n+1)
n=1
while cota(n)>=10^(-6):
    n=n+1
n
# Out:
# 4

# %%
P(x)=taylor(f,x,0,4)
P
# Out:
# x |--> -1/24*x^4 - 1/6*x^3 + 1/2*x^2 + x - 1

# %%
error=abs(f(0.1)-P(0.1))
error.n()<10^(-6)
aprox=P(0.1)

# %%
plot(f,(x,-2,2),color='red',legend_label='y=f(x)$')+plot(P,(x,-2,2),legend_label='x=P(x)$')+point2d([0.1,aprox],size=50, color='black',legend_label='a=aprox$')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Ej 8
f(x)=cos(x)
f
# Out:
# x |--> cos(x)

# %%
cota(n)=0.2^(n+1)/factorial(n+1)
n=1
while cota(n)>=10^(-5):
    n=n+1
n
# Out:
# 4

# %%
P(x)=taylor(f,x,3,4)
P
# Out:
# x |--> 1/24*(x - 3)^4*cos(3) + 1/6*(x - 3)^3*sin(3) - 1/2*(x - 3)^2*cos(3) - (x - 3)*sin(3) + cos(3)

# %%
cota=0.2^5/factorial(5)
error=abs(f(3.2)-P(3.2))
error.n()<10^(-5)
# Out:
# True

# %%
aprox=P(3.2)
aprox.n()
# Out:
# -0.998294487769437

# %%
plot(f,(x,0,7),legend_label='$y=f(x)$',color='red')+plot(P,(x,0,7),legend_label='$x=P(x)$')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
plot(abs(f(x)-P(x)),(x,2.5,3.5))+plot(cota,(x,2.5,3.5),color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
a=find_root(abs(f(x)-P(x))-cota,2,3)
b=find_root(abs(f(x)-P(x))-cota,3,4)
[a,b]
# Out:
# [2.7203026964492567, 3.325856760028344]

# %%
#Ej 9
f(x)=x*(e)^x
f
# Out:
# x |--> x*e^x

# %%
show(diff(f(x),x,1))
show(diff(f(x),x,2))
show(diff(f(x),x,3))
show(diff(f(x),x,4))
show(diff(f(x),x,5))
show(diff(f(x),x,6))
# Out:
# x*e^x + e^x
# x*e^x + 2*e^x
# x*e^x + 3*e^x
# x*e^x + 4*e^x
# x*e^x + 5*e^x
# x*e^x + 6*e^x

# %%
plot((x*exp(x)+exp(x)),(x,-0.5,0))
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
cota(n)=((n+1)*0.5^(n+1))/factorial(n+1)
n=1
while cota(n)>=10^-4:
    n=n+1
n
# Out:
# 6

# %%
P(x)=taylor(f,x,0,n)
aporx=P(-0.5)
aprox
# Out:
# 0.980066666666667*cos(3) - 0.198666666666667*sin(3)

# %%
cota=(n+1)/factorial(7)*0.5^(n+1)
error=abs(f(-0.5)-P(-0.5))
error.n()<10^-4
# Out:
# True

# %%
plot(f,(x,-3,3), legend_label='$y=f(x)$',color='purple')+plot(P,(x,-3,3),legend_label='$x=P(x)$',color='lime')+point2d([-0.5,aprox],size=100,legend_label='$a=aprox$')
# Out:
# Graphics object consisting of 3 graphics primitives

# %%
#Ej10
f(x)=sin(x)
f
# Out:
# x |--> sin(x)

# %%
show(taylor(sin(x),x,0,1))
show(taylor(sin(x),x,0,2))
show(taylor(sin(x),x,0,3))
show(taylor(sin(x),x,0,4))
show(taylor(sin(x),x,0,5))
# Out:
# x
# x
# -1/6*x^3 + x
# -1/6*x^3 + x
# 1/120*x^5 - 1/6*x^3 + x

# %%
P(x)=taylor(f,x,0,4)
P
# Out:
# x |--> -1/6*x^3 + x

# %%
plot(f,-1.2,1.2)+plot(P,-1.2,1.2,color='red')
# Out:
# Graphics object consisting of 2 graphics primitives

# %%
cota(x)=abs(x)^5/factorial(5)
cota(x)
# Out:
# 1/120*abs(x)^5

# %%
r=(120*10^(-3))^(1/5).n()
r
# Out:
# 0.654389389941237

# %%
plot(sin(x),(x,-r-.5,r+.5),legend_label='$y=f(x)$',color='lime')+plot(P,(x,-r-.5,r+.5),legend_label='$x=P(x)$',color='red')+point2d([[r,0]],color='blue',size=50)+point2d([[-r,0]],color='black',size=50)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
plot(abs(f(x)-P(x)),(x,-r-0.5,r+0.5))+plot(10^(-3),(x,-r-0.5,r+0.5),color='red')+point2d([[r,0]],size=50)+point2d([[-r,0]],size=50)
# Out:
# Graphics object consisting of 4 graphics primitives

# %%
#Ej 11
f(x)=cos(x)
f
# Out:
# x |--> cos(x)

# %%
show(taylor(f()))
